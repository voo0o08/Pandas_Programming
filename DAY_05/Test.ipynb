# %%
import pandas as pd

# %%
mi = pd.MultiIndex.from_arrays([list('abb'), list('def')])

# %%
mi
# Out:
# MultiIndex([('a', 'd'),
#             ('b', 'e'),
#             ('b', 'f')],
#            )

# %%
mi.get_loc('a') # -> start end
# Out:
# slice(0, 1, None)

# %%
mi.get_loc('b')
# Out:
# slice(1, 3, None)

# %%
idx = pd.MultiIndex.from_product([(0, 1, 2), ('green', 'purple')],

                                 names=["number", "color"])

# %%
idx
# Out:
# MultiIndex([(0,  'green'),
#             (0, 'purple'),
#             (1,  'green'),
#             (1, 'purple'),
#             (2,  'green'),
#             (2, 'purple')],
#            names=['number', 'color'])

# %%
file = "../DATA/남북한발전전력량.xlsx"
eDF = pd.read_excel(file, index_col=[0, 1])
eDF
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
#           수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
#           신재생        -     -     -     -     -     -     -     -     -     -
# 북한        합계       277   263   247   221   231   230   213   193   170   186
#           수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#           원자력        -     -     -     -     -     -     -     -     -     -
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
#           수력      ...    50    56    56    65    78    77    84    78    58
#           화력      ...  2551  2658  2802  3196  3343  3430  3581  3427  3402
#           원자력     ...  1429  1510  1478  1486  1547  1503  1388  1564  1648
#           신재생     ...     -     -     -     -     -    86   118   151   173
# 북한        합계      ...   236   255   235   237   211   215   221   216   190
#           수력      ...   133   141   125   134   132   135   139   130   100
#           화력      ...   103   114   110   103    79    80    82    86    90
#           원자력     ...     -     -     -     -     -     -     -     -     -
#
#                   2016
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      5404
#           수력        66
#           화력      3523
#           원자력     1620
#           신재생      195
# 북한        합계       239
#           수력       128
#           화력       111
#           원자력        -
#
# [9 rows x 27 columns]

# %%
eDF.drop("신재생", level="발전 전력별")
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
#           수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
# 북한        합계       277   263   247   221   231   230   213   193   170   186
#           수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#           원자력        -     -     -     -     -     -     -     -     -     -
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
#           수력      ...    50    56    56    65    78    77    84    78    58
#           화력      ...  2551  2658  2802  3196  3343  3430  3581  3427  3402
#           원자력     ...  1429  1510  1478  1486  1547  1503  1388  1564  1648
# 북한        합계      ...   236   255   235   237   211   215   221   216   190
#           수력      ...   133   141   125   134   132   135   139   130   100
#           화력      ...   103   114   110   103    79    80    82    86    90
#           원자력     ...     -     -     -     -     -     -     -     -     -
#
#                   2016
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      5404
#           수력        66
#           화력      3523
#           원자력     1620
# 북한        합계       239
#           수력       128
#           화력       111
#           원자력        -
#
# [8 rows x 27 columns]

# %%
eDF.drop(index=("북한", "원자력"))
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
#           수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
#           신재생        -     -     -     -     -     -     -     -     -     -
# 북한        합계       277   263   247   221   231   230   213   193   170   186
#           수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
#           수력      ...    50    56    56    65    78    77    84    78    58
#           화력      ...  2551  2658  2802  3196  3343  3430  3581  3427  3402
#           원자력     ...  1429  1510  1478  1486  1547  1503  1388  1564  1648
#           신재생     ...     -     -     -     -     -    86   118   151   173
# 북한        합계      ...   236   255   235   237   211   215   221   216   190
#           수력      ...   133   141   125   134   132   135   139   130   100
#           화력      ...   103   114   110   103    79    80    82    86    90
#
#                   2016
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      5404
#           수력        66
#           화력      3523
#           원자력     1620
#           신재생      195
# 북한        합계       239
#           수력       128
#           화력       111
#
# [8 rows x 27 columns]

# %%
eDF
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
#           수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
#           신재생        -     -     -     -     -     -     -     -     -     -
# 북한        합계       277   263   247   221   231   230   213   193   170   186
#           수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#           원자력        -     -     -     -     -     -     -     -     -     -
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
#           수력      ...    50    56    56    65    78    77    84    78    58
#           화력      ...  2551  2658  2802  3196  3343  3430  3581  3427  3402
#           원자력     ...  1429  1510  1478  1486  1547  1503  1388  1564  1648
#           신재생     ...     -     -     -     -     -    86   118   151   173
# 북한        합계      ...   236   255   235   237   211   215   221   216   190
#           수력      ...   133   141   125   134   132   135   139   130   100
#           화력      ...   103   114   110   103    79    80    82    86    90
#           원자력     ...     -     -     -     -     -     -     -     -     -
#
#                   2016
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      5404
#           수력        66
#           화력      3523
#           원자력     1620
#           신재생      195
# 북한        합계       239
#           수력       128
#           화력       111
#           원자력        -
#
# [9 rows x 27 columns]

# %%
eDF.index = eDF.index.append(("북한", "신재생"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 eDF.MultiIndex.index = eDF.index.append(("북한", "신재생"))
#
# File ~\anaconda3\envs\My_38\lib\site-packages\pandas\core\indexes\multi.py:2128, in MultiIndex.append(self, other)
#    2125         names.append(label.name if single_label_name else None)
#    2126     return MultiIndex.from_arrays(arrays, names=names)
# -> 2128 to_concat = (self._values,) + tuple(k._values for k in other)
#    2129 new_tuples = np.concatenate(to_concat)
#    2131 # if all(isinstance(x, MultiIndex) for x in other):
#
# File ~\anaconda3\envs\My_38\lib\site-packages\pandas\core\indexes\multi.py:2128, in <genexpr>(.0)
#    2125         names.append(label.name if single_label_name else None)
#    2126     return MultiIndex.from_arrays(arrays, names=names)
# -> 2128 to_concat = (self._values,) + tuple(k._values for k in other)
#    2129 new_tuples = np.concatenate(to_concat)
#    2131 # if all(isinstance(x, MultiIndex) for x in other):
#
# AttributeError: 'str' object has no attribute '_values'

# %%
eDF.loc[("북한", "신재생"),] ="-" # ["-" for i in range(2016-1990+1)]
eDF
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
#           수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
#           신재생        -     -     -     -     -     -     -     -     -     -
# 북한        합계       277   263   247   221   231   230   213   193   170   186
#           수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#           원자력        -     -     -     -     -     -     -     -     -     -
#           신재생        -     -     -     -     -     -     -     -     -     -
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
#           수력      ...    50    56    56    65    78    77    84    78    58
#           화력      ...  2551  2658  2802  3196  3343  3430  3581  3427  3402
#           원자력     ...  1429  1510  1478  1486  1547  1503  1388  1564  1648
#           신재생     ...     -     -     -     -     -    86   118   151   173
# 북한        합계      ...   236   255   235   237   211   215   221   216   190
#           수력      ...   133   141   125   134   132   135   139   130   100
#           화력      ...   103   114   110   103    79    80    82    86    90
#           원자력     ...     -     -     -     -     -     -     -     -     -
#           신재생     ...     -     -     -     -     -     -     -     -     -
#
#                   2016
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      5404
#           수력        66
#           화력      3523
#           원자력     1620
#           신재생      195
# 북한        합계       239
#           수력       128
#           화력       111
#           원자력        -
#           신재생        -
#
# [10 rows x 27 columns]

# %% [markdown]
# # 2번

# %%
file = "../DATA/시도별 전출입 인구수.xlsx"
# 데이터 불러오기
popDF = pd.read_excel(file, index_col=[0, 1], header=[0, 1])
popDF
# Out:
# 전입지별                1970     1971     1972     1973     1974     1975  \
# 전입지별            이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명)
# 전국      전국       4046536  4210164  3687938  4860418  5297969  9011440
#         서울특별시    1742813  1671705  1349333  1831858  2050392  3396662
#         부산광역시     448577   389797   362202   482061   680984   805979
#         대구광역시          -        -        -        -        -        -
#         인천광역시          -        -        -        -        -        -
# ...                  ...      ...      ...      ...      ...      ...
# 제주특별자치도 전라북도         139      202      141      210      219      415
#         전라남도         631      965      857      952     1133     2808
#         경상북도         374      619      468      576      625     1123
#         경상남도         474      479      440      571     1208     1517
#         제주특별자치도     9290    12427    12210    16158    19580    34221
#
# 전입지별                1976     1977     1978     1979  ...     2008     2009  \
# 전입지별            이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명)  ... 이동자수 (명) 이동자수 (명)
# 전국      전국       6773250  7397623  8410276  7324380  ...  8808256  8487275
#         서울특별시    2756510  2893403  3307439  2589667  ...  2025358  1873188
#         부산광역시     724664   785117   895337   809483  ...   514502   519310
#         대구광역시          -        -        -        -  ...   409938   398626
#         인천광역시          -        -        -        -  ...   565585   478169
# ...                  ...      ...      ...      ...  ...      ...      ...
# 제주특별자치도 전라북도         392      408      363      354  ...      668      579
#         전라남도        2608     2652     2722     2178  ...     1143     1123
#         경상북도        1141     1004     1009      818  ...      761      704
#         경상남도         863     1122     1331     1290  ...     1517     1474
#         제주특별자치도    23291    31028    30719    30064  ...    59564    55673
#
# 전입지별                2010     2011     2012     2013     2014     2015  \
# 전입지별            이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명) 이동자수 (명)
# 전국      전국       8226594  8127195  7506691  7411784  7629098  7755286
#         서울특별시    1733015  1721748  1555281  1520090  1573594  1589431
#         부산광역시     519334   508043   461042   478451   485710   507031
#         대구광역시     370817   370563   348642   351873   350213   351424
#         인천광역시     462051   499567   468666   461613   452297   473223
# ...                  ...      ...      ...      ...      ...      ...
# 제주특별자치도 전라북도         672      561      551      516      609      683
#         전라남도        1002     1026      966     1001      928     1062
#         경상북도         738      756      699      781      728      903
#         경상남도        1324     1367     1227     1278     1223     1500
#         제주특별자치도    55507    59846    54280    60607    59673    59036
#
# 전입지별                2016     2017
# 전입지별            이동자수 (명) 이동자수 (명)
# 전국      전국       7378430  7154226
#         서울특별시    1515602  1472937
#         부산광역시     459015   439073
#         대구광역시     328228   321182
#         인천광역시     441646   409465
# ...                  ...      ...
# 제주특별자치도 전라북도         733      768
#         전라남도        1127     1102
#         경상북도         931      994
#         경상남도        1448     1501
#         제주특별자치도    66444    63275
#
# [324 rows x 48 columns]

# %%
popDF["총계", "이동자수 (명)"] = "0"

# %%
popDF.columns
# Out:
# MultiIndex([('1970', '이동자수 (명)'),
#             ('1971', '이동자수 (명)'),
#             ('1972', '이동자수 (명)'),
#             ('1973', '이동자수 (명)'),
#             ('1974', '이동자수 (명)'),
#             ('1975', '이동자수 (명)'),
#             ('1976', '이동자수 (명)'),
#             ('1977', '이동자수 (명)'),
#             ('1978', '이동자수 (명)'),
#             ('1979', '이동자수 (명)'),
#             ('1980', '이동자수 (명)'),
#             ('1981', '이동자수 (명)'),
#             ('1982', '이동자수 (명)'),
#             ('1983', '이동자수 (명)'),
#             ('1984', '이동자수 (명)'),
#             ('1985', '이동자수 (명)'),
#             ('1986', '이동자수 (명)'),
#             ('1987', '이동자수 (명)'),
#             ('1988', '이동자수 (명)'),
#             ('1989', '이동자수 (명)'),
#             ('1990', '이동자수 (명)'),
#             ('1991', '이동자수 (명)'),
#             ('1992', '이동자수 (명)'),
#             ('1993', '이동자수 (명)'),
#             ('1994', '이동자수 (명)'),
#             ('1995', '이동자수 (명)'),
#             ('1996', '이동자수 (명)'),
#             ('1997', '이동자수 (명)'),
#             ('1998', '이동자수 (명)'),
#             ('1999', '이동자수 (명)'),
#             ('2000', '이동자수 (명)'),
#             ('2001', '이동자수 (명)'),
#             ('2002', '이동자수 (명)'),
#             ('2003', '이동자수 (명)'),
#             ('2004', '이동자수 (명)'),
#             ('2005', '이동자수 (명)'),
#             ('2006', '이동자수 (명)'),
#             ('2007', '이동자수 (명)'),
#             ('2008', '이동자수 (명)'),
#             ('2009', '이동자수 (명)'),
#             ('2010', '이동자수 (명)'),
#             ('2011', '이동자수 (명)'),
#             ('2012', '이동자수 (명)'),
#             ('2013', '이동자수 (명)'),
#             ('2014', '이동자수 (명)'),
#             ('2015', '이동자수 (명)'),
#             ('2016', '이동자수 (명)'),
#             ('2017', '이동자수 (명)'),
#             (  '총계', '이동자수 (명)')],
#            names=['전입지별', '전입지별'])

# %%
for i in range(popDF.shape[0]):
    popDF.iloc[i] = popDF.iloc[i].replace("-", "0")
popDF = popDF.astype("int64")
popDF
